# %%
# Initializing a dictionary

grades = { "Math": 25,
         "Physics": 10.8,
         "Chemistry": 11.6 }
grades
# Out:
# {'Chemistry': 11.6, 'Math': 25, 'Physics': 10.8}

# %%
# adding a key-value pair after declaration
grades["English"] = 22.5
grades
# Out:
# {'Chemistry': 11.6, 'English': 22.5, 'Math': 25, 'Physics': 10.8}

# %%
# accessing an element via key
grades["Math"]
# Out:
# 25

# %%
# Iterating a dictionary

for keys in grades:
    print(keys, grades[keys])
# Out:
# Math 25
# Physics 10.8
# Chemistry 11.6
# English 22.5

# %%
grades.keys()
# Out:
# dict_keys(['Math', 'Physics', 'Chemistry', 'English'])

# %%
# nested dictionary
grades["Arts"] = {"History": 44.4, "Music": 55.0}
print(grades)
# Out:
# {'Math': 25, 'Physics': 10.8, 'Chemistry': 11.6, 'English': 22.5, 'Arts': {'History': 44.4, 'Music': 55.0}}

# %%
# removing elements from dictionary

del grades["Math"]
grades
# Out:
# {'Arts': {'History': 44.4, 'Music': 55.0},
#  'Chemistry': 11.6,
#  'English': 22.5,
#  'Physics': 10.8}

# %%
del grades["Arts"]["History"]
grades # removing a nested element
# Out:
# {'Arts': {'Music': 55.0}, 'Chemistry': 11.6, 'English': 22.5, 'Physics': 10.8}

# %%
# deleting the entire dictionary
del grades

# %%
grades
# Out:
# {'Chemistry': 11.6, 'Math': 25, 'Physics': 10.8}
